# %%
import sys

from IPython.core.display_functions import update_display

print(f"Jupyter Notebook 使用的 Python 可执行路径: {sys.executable}")
print(f"Jupyter Notebook 使用的 Python 版本: {sys.version}")
# Out:
# Jupyter Notebook 使用的 Python 可执行路径: /opt/anaconda3/envs/nus/bin/python
# Jupyter Notebook 使用的 Python 版本: 3.10.15 (main, Oct  3 2024, 02:24:49) [Clang 14.0.6 ]

# %%
import matplotlib.pyplot as plt
from IPython import display
from mobile_env.scenarios.custom import MComCustom

# 创建环境实例
env = MComCustom(render_mode="rgb_array")
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.15)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# 数据收集主循环
for idx in range(15):
    # 重置环境，并生成新的基站位置
    env.reset()
    env.save_stations_to_file(idx)
    done = False

    # 模拟用户移动
    for step_number in range(20):
        # 调用 step 方法，模拟时间推进
        info = env.step()

        # 渲染仿真图像
        plt.imshow(env.render())
        display.display(plt.gcf())
        display.clear_output(wait=False)
    env.save_all_step_data(idx)

print("数据收集完成。")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 15
#      13     # 渲染仿真图像
#      14     plt.imshow(env.render())
# ---> 15     display.display(plt.gcf())
#      16     display.clear_output(wait=False)
#      17 # env.save_all_step_data(idx)
#
# File /opt/anaconda3/envs/nus/lib/python3.10/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# ...
